# %% [markdown]
# ### 中国大学排名爬虫
# #### 功能描述
# 输入：大学排名URL
# 输出：排名信息
# url='http://www.zuihaodaxue.cn/zuihaodaxuepaiming2020.html'

# %%
print("{:^10}{:^30}{:^10}".format('排名','学校名称','总分',))
# Out:
#     排名                 学校名称                 总分

# %%
# %run univsitySpidier.py
# Out:
# Suc20
#     排名                                学校名称                                总分
#     1                                 清华大学                              852.5
#     2                                 北京大学                              746.7
#     3                                 浙江大学                              649.2
#     4                                上海交通大学                             625.9
#     5                                 南京大学                              566.1
#     6                                 复旦大学                              556.7
#     7                               中国科学技术大学                            526.4
#     8                                华中科技大学                             497.7
#     9                                 武汉大学                              488.0
#     10                                中山大学                              457.2
#     11                               西安交通大学                             452.5
# ...

# %%
# %run univsitySpidier.py
# Out:
# Suc20
#     排名    	                            学校名称                            	    总分
#     1     	                            清华大学                            	  852.5
#     2     	                            北京大学                            	  746.7
#     3     	                            浙江大学                            	  649.2
#     4     	                           上海交通大学                           	  625.9
#     5     	                            南京大学                            	  566.1
#     6     	                            复旦大学                            	  556.7
#     7     	                          中国科学技术大学                          	  526.4
#     8     	                           华中科技大学                           	  497.7
#     9     	                            武汉大学                            	  488.0
#     10    	                            中山大学                            	  457.2
#     11    	                           西安交通大学                           	  452.5
# ...

# %%
# %run univsitySpidier.py
# Out:
# Suc20
# ----排名----	                            学校名称                            	    总分
# ----1-----	                            清华大学                            	  852.5
# ----2-----	                            北京大学                            	  746.7
# ----3-----	                            浙江大学                            	  649.2
# ----4-----	                           上海交通大学                           	  625.9
# ----5-----	                            南京大学                            	  566.1
# ----6-----	                            复旦大学                            	  556.7
# ----7-----	                          中国科学技术大学                          	  526.4
# ----8-----	                           华中科技大学                           	  497.7
# ----9-----	                            武汉大学                            	  488.0
# ----10----	                            中山大学                            	  457.2
# ----11----	                           西安交通大学                           	  452.5
# ...

# %%
# %run univsitySpidier.py
# Out:
# Suc20
# ----排名----	****************************学校名称****************************	    总分
# ----1-----	****************************清华大学****************************	  852.5
# ----2-----	****************************北京大学****************************	  746.7
# ----3-----	****************************浙江大学****************************	  649.2
# ----4-----	***************************上海交通大学***************************	  625.9
# ----5-----	****************************南京大学****************************	  566.1
# ----6-----	****************************复旦大学****************************	  556.7
# ----7-----	**************************中国科学技术大学**************************	  526.4
# ----8-----	***************************华中科技大学***************************	  497.7
# ----9-----	****************************武汉大学****************************	  488.0
# ----10----	****************************中山大学****************************	  457.2
# ----11----	***************************西安交通大学***************************	  452.5
# ...

# %%
# %run univsitySpidier.py
# Out:
# Suc20
# ----排名----	****************************学校名称****************************	####总分####
# ----1-----	****************************清华大学****************************	##852.5###
# ----2-----	****************************北京大学****************************	##746.7###
# ----3-----	****************************浙江大学****************************	##649.2###
# ----4-----	***************************上海交通大学***************************	##625.9###
# ----5-----	****************************南京大学****************************	##566.1###
# ----6-----	****************************复旦大学****************************	##556.7###
# ----7-----	**************************中国科学技术大学**************************	##526.4###
# ----8-----	***************************华中科技大学***************************	##497.7###
# ----9-----	****************************武汉大学****************************	##488.0###
# ----10----	****************************中山大学****************************	##457.2###
# ...

# %%
# %run univsitySpidier.py
# Out:
# Suc20
# ----排名----****************************学校名称****************************####总分####
# ----1-----****************************清华大学****************************##852.5###
# ----2-----****************************北京大学****************************##746.7###
# ----3-----****************************浙江大学****************************##649.2###
# ----4-----***************************上海交通大学***************************##625.9###
# ----5-----****************************南京大学****************************##566.1###
# ----6-----****************************复旦大学****************************##556.7###
# ----7-----**************************中国科学技术大学**************************##526.4###
# ----8-----***************************华中科技大学***************************##497.7###
# ----9-----****************************武汉大学****************************##488.0###
# ----10----****************************中山大学****************************##457.2###
# ...

# %%
import re
match=re.match(r'[1-9]\d{5}','100081 BIT')

# %%
match.group(0)
# Out:
# '100081'

# %%
match.group(0)
# Out:
# '100081'

# %%
match=re.match(r'[1-9]\d{5}','100081 BIT 125689')

# %%
match.group(1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-88ecb5a672e7> in <module>()
# ----> 1 match.group(1)
#
# IndexError: no such group

# %%
match.group(0)
# Out:
# '100081'

# %%
match.group(0)
# Out:
# '100081'
